# %%
import requests
import pandas as pd

# 1. Setup
HEADERS = {"User-Agent": "MyWeatherApp/1.0"}
LATITUDE = "39.7456"
LONGITUDE = "-97.0892"

# 2. Get Grid Data URL (First API Call)
points_url = f"https://api.weather.gov/points/{LATITUDE},{LONGITUDE}"
try:
    points_response = requests.get(points_url, headers=HEADERS)
    points_response.raise_for_status()
    point_data = points_response.json()
    forecast_url = point_data["properties"]["forecast"]
except requests.exceptions.RequestException as e:
    print(f"Error fetching grid data: {e}")
    exit()

# 3. Fetch Forecast Data (Second API Call)
try:
    forecast_response = requests.get(forecast_url, headers=HEADERS)
    forecast_response.raise_for_status()
    forecast_data = forecast_response.json()
except requests.exceptions.RequestException as e:
    print(f"Error fetching forecast data: {e}")
    exit()

# 4. Extract the List of Forecast Periods
# The actual forecast is a list of dictionaries under 'properties' -> 'periods'
forecast_periods = forecast_data["properties"]["periods"]

# 5. Convert to Pandas DataFrame
# Pandas can directly read a list of dictionaries into a DataFrame
df = pd.DataFrame(forecast_periods)

# 6. Clean and Display the DataFrame (Optional but Recommended)
# Select only the columns you want to display for a cleaner view
df_cleaned = df[
    ["name", "temperature", "temperatureUnit", "windSpeed", "detailedForecast"]
]

# Better-formatted column for temperature
df_cleaned["Temperature"] = (
    df_cleaned["temperature"].astype(str) + " " + df_cleaned["temperatureUnit"]
)
df_cleaned = df_cleaned.drop(columns=["temperature", "temperatureUnit"])

# Rename columns for clarity
df_cleaned.columns = [
    "Time Period",
    "Wind Speed",
    "Detailed Forecast",
    "Temperature",
]

print(df_cleaned)
# Out:
#         Time Period   Wind Speed  \
# 0      Veterans Day        5 mph
# 1           Tonight        5 mph
# 2         Wednesday   0 to 5 mph
# 3   Wednesday Night        5 mph
# 4          Thursday  5 to 10 mph
# 5    Thursday Night        5 mph
# 6            Friday  5 to 10 mph
# 7      Friday Night  5 to 10 mph
# 8          Saturday  5 to 15 mph
# 9    Saturday Night  5 to 10 mph
# 10           Sunday       10 mph
# 11     Sunday Night  5 to 10 mph
# 12           Monday       10 mph
# 13     Monday Night        5 mph
#
#                                     Detailed Forecast Temperature
# 0   Mostly sunny, with a high near 69. West wind a...        69 F
# 1   Mostly clear, with a low around 35. West wind ...        35 F
# 2   Sunny, with a high near 65. Northeast wind 0 t...        65 F
# 3   Partly cloudy, with a low around 42. South win...        42 F
# 4   Mostly sunny, with a high near 67. South wind ...        67 F
# 5   Mostly clear, with a low around 40. South wind...        40 F
# 6   Sunny, with a high near 70. South wind 5 to 10...        70 F
# 7   Partly cloudy, with a low around 50. South win...        50 F
# 8   Mostly sunny, with a high near 71. West wind 5...        71 F
# 9   A slight chance of rain showers after midnight...        40 F
# 10                        Sunny, with a high near 59.        59 F
# 11  A chance of showers and thunderstorms after mi...        38 F
# 12  A chance of rain showers. Partly sunny, with a...        49 F
# 13  A slight chance of rain showers before midnigh...        34 F
# /var/folders/3c/x1npc5yj6655gwzm358m5plh0000gn/T/ipykernel_27097/1402227445.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["Temperature"] = (

# %%
df_cleaned
# Out:
#         Time Period    Wind Speed  \
# 0    This Afternoon        15 mph
# 1           Tonight   0 to 10 mph
# 2         Wednesday    0 to 5 mph
# 3   Wednesday Night    0 to 5 mph
# 4          Thursday   5 to 10 mph
# 5    Thursday Night   5 to 10 mph
# 6            Friday        10 mph
# 7      Friday Night   5 to 10 mph
# 8          Saturday   5 to 10 mph
# 9    Saturday Night         5 mph
# 10           Sunday   5 to 10 mph
# 11     Sunday Night  10 to 15 mph
# 12           Monday        15 mph
# 13     Monday Night        10 mph
#
#                                     Detailed Forecast Temperature
# 0   Sunny, with a high near 63. Northwest wind aro...        63 F
# 1   Clear, with a low around 39. Northwest wind 0 ...        39 F
# 2   Sunny, with a high near 67. Northwest wind 0 t...        67 F
# 3   Mostly clear, with a low around 38. North wind...        38 F
# 4   Sunny, with a high near 65. East wind 5 to 10 ...        65 F
# 5   A chance of rain showers after 1am. Mostly clo...        47 F
# 6   A chance of rain showers before 10am, then a c...        55 F
# 7   A chance of showers and thunderstorms. Cloudy,...        49 F
# 8   A slight chance of rain showers before 1pm. Mo...        60 F
# 9                Mostly cloudy, with a low around 50.        50 F
# 10                Mostly cloudy, with a high near 63.        63 F
# 11  A slight chance of rain showers after 1am. Mos...        52 F
# 12  A chance of rain showers. Mostly cloudy, with ...        63 F
# 13  A chance of rain showers. Mostly cloudy, with ...        43 F

# %%
import requests
import pandas as pd

# Define a list of locations (latitude, longitude, and a friendly name)
LOCATIONS = [
    {"name": "Washington DC", "lat": "38.8894", "lon": "-77.0352"},
    {"name": "San Francisco", "lat": "37.7749", "lon": "-122.4194"},
    {"name": "Miami", "lat": "25.7617", "lon": "-80.1918"},
]

HEADERS = {"User-Agent": "MyMultiRegionApp/1.0"}
ALL_FORECASTS = []


def get_forecast_for_point(lat, lon):
    """Fetches the 7-day forecast URL from the NWS API for a given lat/lon."""
    points_url = f"https://api.weather.gov/points/{lat},{lon}"
    response = requests.get(points_url, headers=HEADERS)
    response.raise_for_status()
    return response.json()["properties"]["forecast"]


def fetch_and_process_forecast(location_info):
    """Fetches the final forecast and processes it into a list of records."""
    name, lat, lon = (
        location_info["name"],
        location_info["lat"],
        location_info["lon"],
    )
    print(f"Fetching data for {name}...")

    try:
        # 1. Get the final forecast URL
        forecast_url = get_forecast_for_point(lat, lon)

        # 2. Fetch the actual forecast data
        forecast_response = requests.get(forecast_url, headers=HEADERS)
        forecast_response.raise_for_status()

        forecast_periods = forecast_response.json()["properties"]["periods"]

        # 3. Add the location name to each period and append to the master list
        for period in forecast_periods:
            period["location_name"] = name  # <-- Add the location identifier
            ALL_FORECASTS.append(period)

    except requests.exceptions.RequestException as e:
        print(f"Skipping {name} due to error: {e}")


# Iterate through all locations
for loc in LOCATIONS:
    fetch_and_process_forecast(loc)

# Create the final DataFrame
if ALL_FORECASTS:
    df = pd.DataFrame(ALL_FORECASTS)

    # Optional: Clean up and select columns
    df_final = df[
        [
            "location_name",
            "name",
            "temperature",
            "temperatureUnit",
            "detailedForecast",
        ]
    ]
    df_final.columns = ["Location", "Time Period", "Temp", "Unit", "Forecast"]

    print("\n--- Consolidated Forecast Data ---")
    print(df_final)
# Out:
# Fetching data for Washington DC...
# Fetching data for San Francisco...
# Fetching data for Miami...
#
# --- Consolidated Forecast Data ---
#          Location      Time Period  Temp Unit  \
# 0   Washington DC   This Afternoon    73    F
# 1   Washington DC          Tonight    50    F
# 2   Washington DC        Wednesday    64    F
# 3   Washington DC  Wednesday Night    44    F
# 4   Washington DC         Thursday    63    F
# 5   Washington DC   Thursday Night    42    F
# 6   Washington DC           Friday    61    F
# 7   Washington DC     Friday Night    41    F
# 8   Washington DC         Saturday    61    F
# 9   Washington DC   Saturday Night    44    F
# 10  Washington DC           Sunday    60    F
# 11  Washington DC     Sunday Night    45    F
# 12  Washington DC           Monday    60    F
# 13  Washington DC     Monday Night    46    F
# 14  San Francisco   This Afternoon    76    F
# 15  San Francisco          Tonight    57    F
# 16  San Francisco        Wednesday    66    F
# 17  San Francisco  Wednesday Night    56    F
# 18  San Francisco         Thursday    67    F
# 19  San Francisco   Thursday Night    56    F
# 20  San Francisco           Friday    69    F
# 21  San Francisco     Friday Night    59    F
# 22  San Francisco         Saturday    67    F
# 23  San Francisco   Saturday Night    56    F
# 24  San Francisco           Sunday    66    F
# 25  San Francisco     Sunday Night    54    F
# 26  San Francisco           Monday    68    F
# 27  San Francisco     Monday Night    54    F
# 28          Miami   This Afternoon    85    F
# 29          Miami          Tonight    77    F
# 30          Miami        Wednesday    85    F
# 31          Miami  Wednesday Night    77    F
# 32          Miami         Thursday    84    F
# 33          Miami   Thursday Night    77    F
# 34          Miami           Friday    83    F
# 35          Miami     Friday Night    78    F
# 36          Miami         Saturday    84    F
# 37          Miami   Saturday Night    78    F
# 38          Miami           Sunday    84    F
# 39          Miami     Sunday Night    78    F
# 40          Miami           Monday    84    F
# 41          Miami     Monday Night    76    F
#
#                                              Forecast
# 0   Mostly sunny, with a high near 73. South wind ...
# 1   Rain showers likely between 7pm and 2am. Mostl...
# 2   Sunny, with a high near 64. West wind 5 to 14 ...
# 3   Mostly clear, with a low around 44. West wind ...
# 4   Sunny, with a high near 63. West wind 5 to 14 ...
# 5                 Mostly clear, with a low around 42.
# 6                         Sunny, with a high near 61.
# 7                 Mostly clear, with a low around 41.
# 8                  Mostly sunny, with a high near 61.
# 9                Mostly cloudy, with a low around 44.
# 10                 Partly sunny, with a high near 60.
# 11  A slight chance of rain showers after 2am. Mos...
# 12  A slight chance of rain showers. Partly sunny,...
# 13  A slight chance of rain showers. Mostly cloudy...
# 14  Sunny. High near 76, with temperatures falling...
# 15  A slight chance of rain between 11pm and 5am. ...
# 16  Partly sunny. High near 66, with temperatures ...
# 17  Mostly cloudy, with a low around 56. West wind...
# 18  Mostly sunny, with a high near 67. West wind 7...
# 19               Partly cloudy, with a low around 56.
# 20                 Mostly sunny, with a high near 69.
# 21  A chance of rain after 11pm. Mostly cloudy, wi...
# 22  A chance of rain. Mostly cloudy, with a high n...
# 23  A chance of rain. Mostly cloudy, with a low ar...
# 24  A chance of rain. Partly sunny, with a high ne...
# 25  A slight chance of rain before 5am. Mostly clo...
# 26                 Mostly sunny, with a high near 68.
# 27                Mostly clear, with a low around 54.
# 28  A slight chance of showers and thunderstorms b...
# 29  Partly cloudy, with a low around 77. East wind...
# 30  Sunny, with a high near 85. Northeast wind 7 t...
# 31  Mostly clear, with a low around 77. Northeast ...
# 32  Sunny, with a high near 84. Northeast wind 13 ...
# 33  Mostly clear, with a low around 77. Northeast ...
# 34  A slight chance of rain showers after 2pm. Sun...
# 35  A slight chance of rain showers before 8pm. Pa...
# 36  A slight chance of rain showers after 2pm. Mos...
# 37  A slight chance of rain showers before 2am. Pa...
# 38  A slight chance of rain showers after 2pm. Mos...
# 39  A slight chance of rain showers before 2am, th...
# 40  A slight chance of showers and thunderstorms b...
# 41  A chance of showers and thunderstorms. Mostly ...

# %%
df_final
# Out:
#          Location      Time Period  Temp Unit  \
# 0   Washington DC   This Afternoon    73    F
# 1   Washington DC          Tonight    50    F
# 2   Washington DC        Wednesday    64    F
# 3   Washington DC  Wednesday Night    44    F
# 4   Washington DC         Thursday    63    F
# 5   Washington DC   Thursday Night    42    F
# 6   Washington DC           Friday    61    F
# 7   Washington DC     Friday Night    41    F
# 8   Washington DC         Saturday    61    F
# 9   Washington DC   Saturday Night    44    F
# 10  Washington DC           Sunday    60    F
# 11  Washington DC     Sunday Night    45    F
# 12  Washington DC           Monday    60    F
# 13  Washington DC     Monday Night    46    F
# 14  San Francisco   This Afternoon    76    F
# 15  San Francisco          Tonight    57    F
# 16  San Francisco        Wednesday    66    F
# 17  San Francisco  Wednesday Night    56    F
# 18  San Francisco         Thursday    67    F
# 19  San Francisco   Thursday Night    56    F
# 20  San Francisco           Friday    69    F
# 21  San Francisco     Friday Night    59    F
# 22  San Francisco         Saturday    67    F
# 23  San Francisco   Saturday Night    56    F
# 24  San Francisco           Sunday    66    F
# 25  San Francisco     Sunday Night    54    F
# 26  San Francisco           Monday    68    F
# 27  San Francisco     Monday Night    54    F
# 28          Miami   This Afternoon    85    F
# 29          Miami          Tonight    77    F
# 30          Miami        Wednesday    85    F
# 31          Miami  Wednesday Night    77    F
# 32          Miami         Thursday    84    F
# 33          Miami   Thursday Night    77    F
# 34          Miami           Friday    83    F
# 35          Miami     Friday Night    78    F
# 36          Miami         Saturday    84    F
# 37          Miami   Saturday Night    78    F
# 38          Miami           Sunday    84    F
# 39          Miami     Sunday Night    78    F
# 40          Miami           Monday    84    F
# 41          Miami     Monday Night    76    F
#
#                                              Forecast
# 0   Mostly sunny, with a high near 73. South wind ...
# 1   Rain showers likely between 7pm and 2am. Mostl...
# 2   Sunny, with a high near 64. West wind 5 to 14 ...
# 3   Mostly clear, with a low around 44. West wind ...
# 4   Sunny, with a high near 63. West wind 5 to 14 ...
# 5                 Mostly clear, with a low around 42.
# 6                         Sunny, with a high near 61.
# 7                 Mostly clear, with a low around 41.
# 8                  Mostly sunny, with a high near 61.
# 9                Mostly cloudy, with a low around 44.
# 10                 Partly sunny, with a high near 60.
# 11  A slight chance of rain showers after 2am. Mos...
# 12  A slight chance of rain showers. Partly sunny,...
# 13  A slight chance of rain showers. Mostly cloudy...
# 14  Sunny. High near 76, with temperatures falling...
# 15  A slight chance of rain between 11pm and 5am. ...
# 16  Partly sunny. High near 66, with temperatures ...
# 17  Mostly cloudy, with a low around 56. West wind...
# 18  Mostly sunny, with a high near 67. West wind 7...
# 19               Partly cloudy, with a low around 56.
# 20                 Mostly sunny, with a high near 69.
# 21  A chance of rain after 11pm. Mostly cloudy, wi...
# 22  A chance of rain. Mostly cloudy, with a high n...
# 23  A chance of rain. Mostly cloudy, with a low ar...
# 24  A chance of rain. Partly sunny, with a high ne...
# 25  A slight chance of rain before 5am. Mostly clo...
# 26                 Mostly sunny, with a high near 68.
# 27                Mostly clear, with a low around 54.
# 28  A slight chance of showers and thunderstorms b...
# 29  Partly cloudy, with a low around 77. East wind...
# 30  Sunny, with a high near 85. Northeast wind 7 t...
# 31  Mostly clear, with a low around 77. Northeast ...
# 32  Sunny, with a high near 84. Northeast wind 13 ...
# 33  Mostly clear, with a low around 77. Northeast ...
# 34  A slight chance of rain showers after 2pm. Sun...
# 35  A slight chance of rain showers before 8pm. Pa...
# 36  A slight chance of rain showers after 2pm. Mos...
# 37  A slight chance of rain showers before 2am. Pa...
# 38  A slight chance of rain showers after 2pm. Mos...
# 39  A slight chance of rain showers before 2am, th...
# 40  A slight chance of showers and thunderstorms b...
# 41  A chance of showers and thunderstorms. Mostly ...

# %%
import requests

# 1. Define your location and a User-Agent
# NOTE: The NWS API requires a User-Agent header that identifies your application/email.
LATITUDE = 38.8951  # Example: Washington D.C.
LONGITUDE = -77.0369
USER_AGENT = "MyWeatherApp/1.0 (contact@example.com)"

HEADERS = {"User-Agent": USER_AGENT, "Accept": "application/geo+json"}


def get_station_id(lat, lon):
    """Step 1: Get the closest weather observation station ID for the coordinates."""
    points_url = f"https://api.weather.gov/points/{lat},{lon}/stations"
    print(f"1. Querying for stations at: {points_url}")

    try:
        response = requests.get(points_url, headers=HEADERS, timeout=10)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()

        # The first feature in the list is usually the closest station
        station_id_url = data["features"][0]["id"]
        station_id = station_id_url.split("/")[-1]
        print(f"-> Closest Station ID found: {station_id}")
        return station_id

    except requests.exceptions.RequestException as e:
        print(f"Error finding station ID: {e}")
        return None


def get_current_observation(station_id):
    """Step 2 & 3: Get and parse the latest observation for the given station ID."""
    if not station_id:
        return

    observation_url = (
        f"https://api.weather.gov/stations/{station_id}/observations/latest"
    )
    print(f"\n2. Querying for latest observation at: {observation_url}")

    try:
        response = requests.get(observation_url, headers=HEADERS, timeout=10)
        response.raise_for_status()
        data = response.json()

        properties = data["properties"]

        # Extracting key observation metrics
        temperature_c = properties["temperature"]["value"]
        wind_speed_mps = properties["windSpeed"]["value"]
        wind_direction_deg = properties["windDirection"]["value"]
        text_description = properties["textDescription"]

        # NOTE on Units: NWS API returns data in metric (mostly Celsius and m/s).
        # You would need to convert these values for imperial units.

        print("\n--- Current Observation ---")
        print(f"Station: {station_id}")
        print(f"Description: {text_description}")
        print(f"Temperature: {temperature_c:.2f}°C")

        if wind_speed_mps is not None:
            print(f"Wind Speed: {wind_speed_mps:.2f} m/s")
        else:
            print("Wind Speed: N/A")

        if wind_direction_deg is not None:
            print(f"Wind Direction: {wind_direction_deg}°")
        else:
            print("Wind Direction: N/A")

        print("---------------------------")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching observation data: {e}")
    except KeyError as e:
        print(
            f"Error parsing data (missing key): {e}. Station data may be incomplete."
        )


# --- Execution ---
station = get_station_id(LATITUDE, LONGITUDE)
print(station)
get_current_observation(station)
# Out:
# 1. Querying for stations at: https://api.weather.gov/points/38.8951,-77.0369/stations
# -> Closest Station ID found: KDCA
# KDCA
#
# 2. Querying for latest observation at: https://api.weather.gov/stations/KDCA/observations/latest
#
# --- Current Observation ---
# Station: KDCA
# Description: Clear
# Temperature: 16.00°C
# Wind Speed: N/A
# Wind Direction: N/A
# ---------------------------

# %%
import requests

TOKEN = "FhaIFQelGOSdLrnxCfCTvRMHAKeErqLC"
STATION_ID = "GHCND:USW00093721"  # Example station ID format for NOAA CDO
START_DATE = "2023-01-01"
END_DATE = "2023-01-31"

headers = {"token": TOKEN}

params = {
    "datasetid": "GHCND",  # daily summaries dataset
    "stationid": STATION_ID,
    "startdate": START_DATE,
    "enddate": END_DATE,
    "limit": 1000,
    "units": "metric",
}

url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"

response = requests.get(url, headers=headers, params=params)
data = response.json()

for result in data["results"]:
    print(result)
# Out:
# {'date': '2023-01-01T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 67}
# {'date': '2023-01-01T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10149}
# {'date': '2023-01-01T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10085}
# {'date': '2023-01-01T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 89}
# {'date': '2023-01-01T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.4}
# {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-01T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 76}
# {'date': '2023-01-01T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 41}
# {'date': '2023-01-01T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 97}
# {'date': '2023-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-01T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-01T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 12.6}
# {'date': '2023-01-01T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 17.8}
# {'date': '2023-01-01T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 4.4}
# {'date': '2023-01-01T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 270}
# {'date': '2023-01-01T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-01T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-01T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-01T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-02T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 67}
# {'date': '2023-01-02T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10193}
# {'date': '2023-01-02T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10132}
# {'date': '2023-01-02T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 83}
# {'date': '2023-01-02T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.9}
# {'date': '2023-01-02T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-02T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 76}
# {'date': '2023-01-02T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 49}
# {'date': '2023-01-02T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-02T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-02T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-02T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 9.7}
# {'date': '2023-01-02T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 18.9}
# {'date': '2023-01-02T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 4.4}
# {'date': '2023-01-02T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 90}
# {'date': '2023-01-02T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-02T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.6}
# {'date': '2023-01-02T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.4}
# {'date': '2023-01-03T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 106}
# {'date': '2023-01-03T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10132}
# {'date': '2023-01-03T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10085}
# {'date': '2023-01-03T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 122}
# {'date': '2023-01-03T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.4}
# {'date': '2023-01-03T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': 'T,,W,2400', 'value': 0.0}
# {'date': '2023-01-03T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 77}
# {'date': '2023-01-03T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 62}
# {'date': '2023-01-03T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-03T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-03T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-03T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 12.7}
# {'date': '2023-01-03T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 20.6}
# {'date': '2023-01-03T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 7.2}
# {'date': '2023-01-03T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 210}
# {'date': '2023-01-03T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 220}
# {'date': '2023-01-03T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.9}
# {'date': '2023-01-03T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 14.8}
# {'date': '2023-01-03T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-04T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 139}
# {'date': '2023-01-04T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10098}
# {'date': '2023-01-04T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10041}
# {'date': '2023-01-04T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 150}
# {'date': '2023-01-04T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.3}
# {'date': '2023-01-04T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': 'T,,W,2400', 'value': 0.0}
# {'date': '2023-01-04T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 82}
# {'date': '2023-01-04T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 68}
# {'date': '2023-01-04T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 90}
# {'date': '2023-01-04T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-04T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-04T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 17.4}
# {'date': '2023-01-04T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 18.9}
# {'date': '2023-01-04T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 11.7}
# {'date': '2023-01-04T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 240}
# {'date': '2023-01-04T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 230}
# {'date': '2023-01-04T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-04T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11.6}
# {'date': '2023-01-05T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 72}
# {'date': '2023-01-05T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10132}
# {'date': '2023-01-05T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10068}
# {'date': '2023-01-05T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 106}
# {'date': '2023-01-05T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.9}
# {'date': '2023-01-05T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 2.8}
# {'date': '2023-01-05T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 65}
# {'date': '2023-01-05T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 43}
# {'date': '2023-01-05T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-05T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-05T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-05T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 15.6}
# {'date': '2023-01-05T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 17.8}
# {'date': '2023-01-05T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 9.4}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 310}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 340}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.3}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.5}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-05T00:00:00', 'datatype': 'WT03', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-06T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6}
# {'date': '2023-01-06T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10179}
# {'date': '2023-01-06T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10112}
# {'date': '2023-01-06T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-06T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.8}
# {'date': '2023-01-06T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-06T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 62}
# {'date': '2023-01-06T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 44}
# {'date': '2023-01-06T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-06T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-06T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-06T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 9.1}
# {'date': '2023-01-06T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 11.1}
# {'date': '2023-01-06T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.9}
# {'date': '2023-01-06T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-06T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 300}
# {'date': '2023-01-06T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-06T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 15.2}
# {'date': '2023-01-07T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -28}
# {'date': '2023-01-07T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10240}
# {'date': '2023-01-07T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10176}
# {'date': '2023-01-07T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 22}
# {'date': '2023-01-07T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.1}
# {'date': '2023-01-07T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-07T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 57}
# {'date': '2023-01-07T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 39}
# {'date': '2023-01-07T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 73}
# {'date': '2023-01-07T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-07T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-07T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 6.3}
# {'date': '2023-01-07T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 10.0}
# {'date': '2023-01-07T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 1.7}
# {'date': '2023-01-07T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-07T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-07T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.1}
# {'date': '2023-01-07T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11.2}
# {'date': '2023-01-08T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -28}
# {'date': '2023-01-08T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10251}
# {'date': '2023-01-08T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10196}
# {'date': '2023-01-08T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6}
# {'date': '2023-01-08T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.0}
# {'date': '2023-01-08T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.3}
# {'date': '2023-01-08T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 67}
# {'date': '2023-01-08T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 47}
# {'date': '2023-01-08T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-08T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-08T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-08T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 2.8}
# {'date': '2023-01-08T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 6.7}
# {'date': '2023-01-08T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -2.7}
# {'date': '2023-01-08T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 190}
# {'date': '2023-01-08T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 190}
# {'date': '2023-01-08T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.5}
# {'date': '2023-01-08T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-08T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-09T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -22}
# {'date': '2023-01-09T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10163}
# {'date': '2023-01-09T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10105}
# {'date': '2023-01-09T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 22}
# {'date': '2023-01-09T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.5}
# {'date': '2023-01-09T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.3}
# {'date': '2023-01-09T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 62}
# {'date': '2023-01-09T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 32}
# {'date': '2023-01-09T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 97}
# {'date': '2023-01-09T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-09T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-09T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 5.3}
# {'date': '2023-01-09T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 10.0}
# {'date': '2023-01-09T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 1.1}
# {'date': '2023-01-09T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-09T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-09T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.1}
# {'date': '2023-01-09T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11.2}
# {'date': '2023-01-09T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-10T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -39}
# {'date': '2023-01-10T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10186}
# {'date': '2023-01-10T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10125}
# {'date': '2023-01-10T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11}
# {'date': '2023-01-10T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.6}
# {'date': '2023-01-10T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-10T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 60}
# {'date': '2023-01-10T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 42}
# {'date': '2023-01-10T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 82}
# {'date': '2023-01-10T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-10T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-10T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 4.2}
# {'date': '2023-01-10T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 9.4}
# {'date': '2023-01-10T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -1.6}
# {'date': '2023-01-10T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 330}
# {'date': '2023-01-10T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-10T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.4}
# {'date': '2023-01-10T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.7}
# {'date': '2023-01-11T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -17}
# {'date': '2023-01-11T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10220}
# {'date': '2023-01-11T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10152}
# {'date': '2023-01-11T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11}
# {'date': '2023-01-11T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.4}
# {'date': '2023-01-11T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-11T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 73}
# {'date': '2023-01-11T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 54}
# {'date': '2023-01-11T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 89}
# {'date': '2023-01-11T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-11T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-11T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 2.3}
# {'date': '2023-01-11T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 7.8}
# {'date': '2023-01-11T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -3.8}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 110}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 130}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.4}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-11T00:00:00', 'datatype': 'WT08', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-12T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 61}
# {'date': '2023-01-12T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10135}
# {'date': '2023-01-12T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10098}
# {'date': '2023-01-12T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 72}
# {'date': '2023-01-12T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.2}
# {'date': '2023-01-12T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 2.3}
# {'date': '2023-01-12T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 86}
# {'date': '2023-01-12T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 77}
# {'date': '2023-01-12T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-12T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-12T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-12T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 6.8}
# {'date': '2023-01-12T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 13.3}
# {'date': '2023-01-12T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 4.4}
# {'date': '2023-01-12T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 60}
# {'date': '2023-01-12T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 210}
# {'date': '2023-01-12T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.5}
# {'date': '2023-01-12T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-12T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-13T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 28}
# {'date': '2023-01-13T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10051}
# {'date': '2023-01-13T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 9986}
# {'date': '2023-01-13T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 61}
# {'date': '2023-01-13T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.2}
# {'date': '2023-01-13T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.0}
# {'date': '2023-01-13T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 67}
# {'date': '2023-01-13T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-13T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-13T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-13T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-13T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 10.4}
# {'date': '2023-01-13T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 13.3}
# {'date': '2023-01-13T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.9}
# {'date': '2023-01-13T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-13T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 330}
# {'date': '2023-01-13T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.7}
# {'date': '2023-01-13T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 14.8}
# {'date': '2023-01-13T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-14T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -61}
# {'date': '2023-01-14T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10125}
# {'date': '2023-01-14T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10064}
# {'date': '2023-01-14T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -11}
# {'date': '2023-01-14T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.2}
# {'date': '2023-01-14T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-14T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 57}
# {'date': '2023-01-14T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-14T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 62}
# {'date': '2023-01-14T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-14T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-14T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 2.8}
# {'date': '2023-01-14T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.9}
# {'date': '2023-01-14T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -0.5}
# {'date': '2023-01-14T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 340}
# {'date': '2023-01-14T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 360}
# {'date': '2023-01-14T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11.6}
# {'date': '2023-01-14T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 16.5}
# {'date': '2023-01-15T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -72}
# {'date': '2023-01-15T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10183}
# {'date': '2023-01-15T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10125}
# {'date': '2023-01-15T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -11}
# {'date': '2023-01-15T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.4}
# {'date': '2023-01-15T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-15T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 48}
# {'date': '2023-01-15T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 35}
# {'date': '2023-01-15T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 61}
# {'date': '2023-01-15T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-15T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-15T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 2.2}
# {'date': '2023-01-15T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 7.8}
# {'date': '2023-01-15T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -1.0}
# {'date': '2023-01-15T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 330}
# {'date': '2023-01-15T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 310}
# {'date': '2023-01-15T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 9.8}
# {'date': '2023-01-15T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 13.9}
# {'date': '2023-01-16T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -106}
# {'date': '2023-01-16T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10149}
# {'date': '2023-01-16T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10091}
# {'date': '2023-01-16T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0}
# {'date': '2023-01-16T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.2}
# {'date': '2023-01-16T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-16T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 32}
# {'date': '2023-01-16T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 17}
# {'date': '2023-01-16T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 49}
# {'date': '2023-01-16T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-16T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-16T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 5.0}
# {'date': '2023-01-16T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 13.3}
# {'date': '2023-01-16T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -1.6}
# {'date': '2023-01-16T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 300}
# {'date': '2023-01-16T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 300}
# {'date': '2023-01-16T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.6}
# {'date': '2023-01-16T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.7}
# {'date': '2023-01-17T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 17}
# {'date': '2023-01-17T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10071}
# {'date': '2023-01-17T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10010}
# {'date': '2023-01-17T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 44}
# {'date': '2023-01-17T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.7}
# {'date': '2023-01-17T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': 'T,,W,2400', 'value': 0.0}
# {'date': '2023-01-17T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 73}
# {'date': '2023-01-17T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 48}
# {'date': '2023-01-17T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 96}
# {'date': '2023-01-17T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-17T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-17T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 5.5}
# {'date': '2023-01-17T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 10.0}
# {'date': '2023-01-17T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 1.7}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 220}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 220}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.5}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.7}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-17T00:00:00', 'datatype': 'WT02', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-18T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 33}
# {'date': '2023-01-18T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10125}
# {'date': '2023-01-18T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10058}
# {'date': '2023-01-18T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 61}
# {'date': '2023-01-18T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.3}
# {'date': '2023-01-18T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-18T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 69}
# {'date': '2023-01-18T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 46}
# {'date': '2023-01-18T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 97}
# {'date': '2023-01-18T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-18T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-18T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 9.1}
# {'date': '2023-01-18T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 13.9}
# {'date': '2023-01-18T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.9}
# {'date': '2023-01-18T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 300}
# {'date': '2023-01-18T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-18T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 9.8}
# {'date': '2023-01-18T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 14.3}
# {'date': '2023-01-18T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-19T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 39}
# {'date': '2023-01-19T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10105}
# {'date': '2023-01-19T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10030}
# {'date': '2023-01-19T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-19T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.5}
# {'date': '2023-01-19T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 4.3}
# {'date': '2023-01-19T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 87}
# {'date': '2023-01-19T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 71}
# {'date': '2023-01-19T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 97}
# {'date': '2023-01-19T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-19T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-19T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 6.2}
# {'date': '2023-01-19T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 6.7}
# {'date': '2023-01-19T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 5.0}
# {'date': '2023-01-19T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 290}
# {'date': '2023-01-19T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 300}
# {'date': '2023-01-19T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.3}
# {'date': '2023-01-19T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.5}
# {'date': '2023-01-19T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-20T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -6}
# {'date': '2023-01-20T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10105}
# {'date': '2023-01-20T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10030}
# {'date': '2023-01-20T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 39}
# {'date': '2023-01-20T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.6}
# {'date': '2023-01-20T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-20T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 58}
# {'date': '2023-01-20T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 40}
# {'date': '2023-01-20T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 96}
# {'date': '2023-01-20T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-20T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-20T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 7.6}
# {'date': '2023-01-20T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 11.7}
# {'date': '2023-01-20T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.3}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 270}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 14.3}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 19.2}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-20T00:00:00', 'datatype': 'WT02', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-21T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -39}
# {'date': '2023-01-21T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10217}
# {'date': '2023-01-21T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10163}
# {'date': '2023-01-21T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11}
# {'date': '2023-01-21T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.9}
# {'date': '2023-01-21T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-21T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 56}
# {'date': '2023-01-21T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 45}
# {'date': '2023-01-21T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 72}
# {'date': '2023-01-21T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-21T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-21T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 4.9}
# {'date': '2023-01-21T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 7.2}
# {'date': '2023-01-21T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -1.0}
# {'date': '2023-01-21T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 350}
# {'date': '2023-01-21T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 330}
# {'date': '2023-01-21T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 7.2}
# {'date': '2023-01-21T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-22T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0}
# {'date': '2023-01-22T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10163}
# {'date': '2023-01-22T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10088}
# ...
# {'date': '2023-01-24T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11.6}
# {'date': '2023-01-25T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 22}
# {'date': '2023-01-25T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10152}
# {'date': '2023-01-25T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10064}
# {'date': '2023-01-25T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 39}
# {'date': '2023-01-25T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 3.5}
# {'date': '2023-01-25T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 16.3}
# {'date': '2023-01-25T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 85}
# {'date': '2023-01-25T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 65}
# {'date': '2023-01-25T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 97}
# {'date': '2023-01-25T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': 'T,,W,', 'value': 0.0}
# {'date': '2023-01-25T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-25T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 3.3}
# {'date': '2023-01-25T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 11.1}
# {'date': '2023-01-25T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -0.5}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 100}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 90}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.1}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-25T00:00:00', 'datatype': 'WT04', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-26T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -17}
# {'date': '2023-01-26T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10081}
# {'date': '2023-01-26T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10027}
# {'date': '2023-01-26T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 33}
# {'date': '2023-01-26T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 5.9}
# {'date': '2023-01-26T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-26T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 58}
# {'date': '2023-01-26T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 41}
# {'date': '2023-01-26T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-26T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-26T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-26T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 7.8}
# {'date': '2023-01-26T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 10.0}
# {'date': '2023-01-26T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 1.7}
# {'date': '2023-01-26T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 270}
# {'date': '2023-01-26T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 260}
# {'date': '2023-01-26T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 12.5}
# {'date': '2023-01-26T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 17.0}
# {'date': '2023-01-27T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -78}
# {'date': '2023-01-27T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10203}
# {'date': '2023-01-27T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10146}
# {'date': '2023-01-27T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -6}
# {'date': '2023-01-27T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.1}
# {'date': '2023-01-27T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-27T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 45}
# {'date': '2023-01-27T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 29}
# {'date': '2023-01-27T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 67}
# {'date': '2023-01-27T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-27T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-27T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 3.7}
# {'date': '2023-01-27T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 7.2}
# {'date': '2023-01-27T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -2.7}
# {'date': '2023-01-27T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 280}
# {'date': '2023-01-27T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 260}
# {'date': '2023-01-27T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-27T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 14.8}
# {'date': '2023-01-28T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': -39}
# {'date': '2023-01-28T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10247}
# {'date': '2023-01-28T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10190}
# {'date': '2023-01-28T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 22}
# {'date': '2023-01-28T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.9}
# {'date': '2023-01-28T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-28T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 50}
# {'date': '2023-01-28T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 34}
# {'date': '2023-01-28T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 76}
# {'date': '2023-01-28T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-28T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-28T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 5.4}
# {'date': '2023-01-28T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 13.9}
# {'date': '2023-01-28T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-28T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 230}
# {'date': '2023-01-28T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 230}
# {'date': '2023-01-28T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.7}
# {'date': '2023-01-28T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 9.8}
# {'date': '2023-01-29T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 11}
# {'date': '2023-01-29T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10230}
# {'date': '2023-01-29T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10169}
# {'date': '2023-01-29T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 33}
# {'date': '2023-01-29T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.8}
# {'date': '2023-01-29T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': 'T,,W,2400', 'value': 0.0}
# {'date': '2023-01-29T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 75}
# {'date': '2023-01-29T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 44}
# {'date': '2023-01-29T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 93}
# {'date': '2023-01-29T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-29T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-29T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 4.8}
# {'date': '2023-01-29T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 11.1}
# {'date': '2023-01-29T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': -1.0}
# {'date': '2023-01-29T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 220}
# {'date': '2023-01-29T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 250}
# {'date': '2023-01-29T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 8.1}
# {'date': '2023-01-29T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 12.5}
# {'date': '2023-01-30T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 39}
# {'date': '2023-01-30T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10207}
# {'date': '2023-01-30T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10152}
# {'date': '2023-01-30T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 61}
# {'date': '2023-01-30T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1.1}
# {'date': '2023-01-30T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 0.0}
# {'date': '2023-01-30T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 76}
# {'date': '2023-01-30T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 49}
# {'date': '2023-01-30T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 96}
# {'date': '2023-01-30T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-30T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-30T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 8.1}
# {'date': '2023-01-30T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 15.0}
# {'date': '2023-01-30T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 3.3}
# {'date': '2023-01-30T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 160}
# {'date': '2023-01-30T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 150}
# {'date': '2023-01-30T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 4.0}
# {'date': '2023-01-30T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.3}
# {'date': '2023-01-30T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-31T00:00:00', 'datatype': 'ADPT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 17}
# {'date': '2023-01-31T00:00:00', 'datatype': 'ASLP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10220}
# {'date': '2023-01-31T00:00:00', 'datatype': 'ASTP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10156}
# {'date': '2023-01-31T00:00:00', 'datatype': 'AWBT', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 33}
# {'date': '2023-01-31T00:00:00', 'datatype': 'AWND', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 2.3}
# {'date': '2023-01-31T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 2.5}
# {'date': '2023-01-31T00:00:00', 'datatype': 'RHAV', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 80}
# {'date': '2023-01-31T00:00:00', 'datatype': 'RHMN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 66}
# {'date': '2023-01-31T00:00:00', 'datatype': 'RHMX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 89}
# {'date': '2023-01-31T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-31T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 0.0}
# {'date': '2023-01-31T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00093721', 'attributes': 'H,,S,', 'value': 6.2}
# {'date': '2023-01-31T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 8.9}
# {'date': '2023-01-31T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USW00093721', 'attributes': ',,W,2400', 'value': 2.2}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WDF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 340}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WDF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WSF2', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 6.7}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WSF5', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 10.3}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WT01', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}
# {'date': '2023-01-31T00:00:00', 'datatype': 'WT08', 'station': 'GHCND:USW00093721', 'attributes': ',,W,', 'value': 1}

# %%
observation_url = f"https://api.weather.gov/stations/FRDW1/observations/latest"
print(f"\n2. Querying for latest observation at: {observation_url}")

response = requests.get(observation_url, headers=HEADERS, timeout=10)
response.raise_for_status()
data = response.json()
# Out:
# 2. Querying for latest observation at: https://api.weather.gov/stations/FRDW1/observations/latest

# %%
data
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/stations/FRDW1/observations/2025-11-11T22:42:00+00:00',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-123.01, 48.55]},
#  'properties': {'@id': 'https://api.weather.gov/stations/FRDW1/observations/2025-11-11T22:42:00+00:00',
#   '@type': 'wx:ObservationStation',
#   'elevation': {'unitCode': 'wmoUnit:m', 'value': 0},
#   'station': 'https://api.weather.gov/stations/FRDW1',
#   'stationId': 'FRDW1',
#   'stationName': 'Friday Harbor',
#   'timestamp': '2025-11-11T22:42:00+00:00',
#   'rawMessage': '',
#   'textDescription': '',
#   'icon': None,
#   'presentWeather': [],
#   'temperature': {'unitCode': 'wmoUnit:degC',
#    'value': 10,
#    'qualityControl': 'V'},
#   'dewpoint': {'unitCode': 'wmoUnit:degC',
#    'value': None,
#    'qualityControl': 'Z'},
#   'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#    'value': 68,
#    'qualityControl': 'V'},
#   'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#    'value': 3.204,
#    'qualityControl': 'V'},
#   'windGust': {'unitCode': 'wmoUnit:km_h-1',
#    'value': 6.444,
#    'qualityControl': 'S'},
#   'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#    'value': 101964.17,
#    'qualityControl': 'V'},
#   'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#    'value': None,
#    'qualityControl': 'Z'},
#   'visibility': {'unitCode': 'wmoUnit:m',
#    'value': None,
#    'qualityControl': 'Z'},
#   'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#   'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#   'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#    'value': None,
#    'qualityControl': 'Z'},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#    'value': None,
#    'qualityControl': 'V'},
#   'windChill': {'unitCode': 'wmoUnit:degC',
#    'value': None,
#    'qualityControl': 'V'},
#   'heatIndex': {'unitCode': 'wmoUnit:degC',
#    'value': None,
#    'qualityControl': 'V'},
#   'cloudLayers': []}}
